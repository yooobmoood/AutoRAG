# %%
# import nest_asyncio
# nest_asyncio.apply()

# from autorag.chunker import Chunker

# chunker = Chunker.from_parquet(parsed_data_path="./parse/0.parquet")
# chunker.start_chunking("./config/chunk.yaml")

# %%
import pandas as pd
from rich.console import Console

console = Console()

# %%
chunk_0 = pd.read_parquet('./chunk/0.parquet', engine='pyarrow')
chunk_0.head()
# Out:
#                                  doc_id  \
# 0  34f8b7da-3c84-425e-900b-98e82bc434da
# 1  b3699e59-5c49-4f17-a36a-91de667d5e3f
# 2  65ac17ae-68c1-4491-a9ad-4c0936218f47
# 3  897ab10c-fa9b-4929-845d-00a168233ace
# 4  d72ec233-fb6f-4330-a1ae-212a671e082a
#
#                                             contents                     path  \
# 0  파일 제목: 700words.csv\n 내용: title: 가계부실위험지수(HDRI...  ./raw_docs/700words.csv
# 1  파일 제목: 700words.csv\n 내용: title: 가계수지\ncontent...  ./raw_docs/700words.csv
# 2  파일 제목: 700words.csv\n 내용: title: 가계순저축률\nconte...  ./raw_docs/700words.csv
# 3  파일 제목: 700words.csv\n 내용: title: 가계신용통계\nconte...  ./raw_docs/700words.csv
# 4  파일 제목: 700words.csv\n 내용: title: 가계처분가능소득\ncon...  ./raw_docs/700words.csv
#
#   start_end_idx                                           metadata
# 0      [0, 522]  {'last_modified_datetime': '2024-10-24', 'page...
# 1      [0, 453]  {'last_modified_datetime': '2024-10-24', 'page...
# 2      [0, 422]  {'last_modified_datetime': '2024-10-24', 'page...
# 3      [0, 256]  {'last_modified_datetime': '2024-10-24', 'page...
# 4      [0, 447]  {'last_modified_datetime': '2024-10-24', 'page...

# %%
chunk_0 = pd.read_parquet('./chunk/0.parquet', engine='pyarrow')
chunk_1 = pd.read_parquet('./chunk/1.parquet', engine='pyarrow')
chunk_2 = pd.read_parquet('./chunk/2.parquet', engine='pyarrow')
chunk_3 = pd.read_parquet('./chunk/3.parquet', engine='pyarrow')
chunk_4 = pd.read_parquet('./chunk/4.parquet', engine='pyarrow')
chunk_5 = pd.read_parquet('./chunk/5.parquet', engine='pyarrow')
chunk_6 = pd.read_parquet('./chunk/6.parquet', engine='pyarrow')
chunk_7 = pd.read_parquet('./chunk/7.parquet', engine='pyarrow')

# %%
print(chunk_0.head())
print("---------------------------------")
print(chunk_1.head())
print("---------------------------------")
print(chunk_2.head())
print("---------------------------------")
print(chunk_3.head())
print("---------------------------------")
print(chunk_4.head())
print("---------------------------------")
print(chunk_5.head())
print("---------------------------------")
print(chunk_6.head())
print("---------------------------------")
print(chunk_7.head())
# Out:
#                                  doc_id  \
# 0  34f8b7da-3c84-425e-900b-98e82bc434da
# 1  b3699e59-5c49-4f17-a36a-91de667d5e3f
# 2  65ac17ae-68c1-4491-a9ad-4c0936218f47
# 3  897ab10c-fa9b-4929-845d-00a168233ace
# 4  d72ec233-fb6f-4330-a1ae-212a671e082a
#
#                                             contents                     path  \
# 0  파일 제목: 700words.csv\n 내용: title: 가계부실위험지수(HDRI...  ./raw_docs/700words.csv
# 1  파일 제목: 700words.csv\n 내용: title: 가계수지\ncontent...  ./raw_docs/700words.csv
# 2  파일 제목: 700words.csv\n 내용: title: 가계순저축률\nconte...  ./raw_docs/700words.csv
# 3  파일 제목: 700words.csv\n 내용: title: 가계신용통계\nconte...  ./raw_docs/700words.csv
# 4  파일 제목: 700words.csv\n 내용: title: 가계처분가능소득\ncon...  ./raw_docs/700words.csv
#
#   start_end_idx                                           metadata
# 0      [0, 522]  {'last_modified_datetime': '2024-10-24', 'page...
# 1      [0, 453]  {'last_modified_datetime': '2024-10-24', 'page...
# 2      [0, 422]  {'last_modified_datetime': '2024-10-24', 'page...
# 3      [0, 256]  {'last_modified_datetime': '2024-10-24', 'page...
# 4      [0, 447]  {'last_modified_datetime': '2024-10-24', 'page...
# ---------------------------------
#                                  doc_id  \
# 0  c1dbb444-0155-4333-9e12-97bc3bda98fd
# 1  a77bbb53-ada8-408a-a780-c4d8c5a008bd
# 2  b1e1babd-f093-4afb-8c68-24bef12035d3
# 3  cd3da2c5-1e76-47d4-bb7b-354cace6ca74
# 4  1176ac6a-afa0-4bee-98de-e93b6ed1652c
#
#                                             contents                     path  \
# 0  파일 제목: 700words.csv\n 내용: title: 가계부실위험지수(HDRI...  ./raw_docs/700words.csv
# 1  파일 제목: 700words.csv\n 내용: title: 가계수지\ncontent...  ./raw_docs/700words.csv
# 2  파일 제목: 700words.csv\n 내용: title: 가계순저축률\nconte...  ./raw_docs/700words.csv
# 3  파일 제목: 700words.csv\n 내용: title: 가계신용통계\nconte...  ./raw_docs/700words.csv
# 4  파일 제목: 700words.csv\n 내용: title: 가계처분가능소득\ncon...  ./raw_docs/700words.csv
#
#   start_end_idx                                           metadata
# 0      [0, 522]  {'last_modified_datetime': '2024-10-24', 'page...
# 1      [0, 453]  {'last_modified_datetime': '2024-10-24', 'page...
# 2      [0, 422]  {'last_modified_datetime': '2024-10-24', 'page...
# 3      [0, 256]  {'last_modified_datetime': '2024-10-24', 'page...
# 4      [0, 447]  {'last_modified_datetime': '2024-10-24', 'page...
# ---------------------------------
#                                  doc_id  \
# 0  b51e0242-40f4-423a-9e89-e99f7e4ff2ec
# 1  4d091b89-cb05-45db-9915-f364f278d061
# 2  a8e4254f-e851-46c3-9db8-f09e7a9e60db
# 3  b0ecfa0e-090a-43b1-8202-f7d43effec55
# 4  d2e86692-9e04-47ab-ae3b-16345ec85438
#
#                                             contents                     path  \
# 0  파일 제목: 700words.csv\n 내용: title: 가계부실위험지수(HDRI...  ./raw_docs/700words.csv
# 1  파일 제목: 700words.csv\n 내용: title: 가계수지\ncontent...  ./raw_docs/700words.csv
# 2  파일 제목: 700words.csv\n 내용: title: 가계순저축률\nconte...  ./raw_docs/700words.csv
# 3  파일 제목: 700words.csv\n 내용: title: 가계신용통계\nconte...  ./raw_docs/700words.csv
# 4  파일 제목: 700words.csv\n 내용: title: 가계처분가능소득\ncon...  ./raw_docs/700words.csv
#
#   start_end_idx                                           metadata
# 0      [0, 522]  {'last_modified_datetime': '2024-10-24', 'next...
# 1      [0, 453]  {'last_modified_datetime': '2024-10-24', 'next...
# 2      [0, 422]  {'last_modified_datetime': '2024-10-24', 'next...
# 3      [0, 256]  {'last_modified_datetime': '2024-10-24', 'next...
# 4      [0, 447]  {'last_modified_datetime': '2024-10-24', 'next...
# ---------------------------------
#                                  doc_id  \
# 0  0181fd3f-c53a-4671-bf8f-d8d80c132f56
# 1  483d1c43-5520-49f2-9ccc-992a9675b1a7
# 2  04f1aaa7-9502-4d77-8da8-1c44dfc96cfd
# 3  27652ec8-289a-4353-9b10-c0bbcea47da8
# 4  b79a48d7-50e3-4787-916f-b4d4fdda97c0
#
#                                             contents                     path  \
# 0  파일 제목: 700words.csv\n 내용: title: 가계부실위험지수(HDRI...  ./raw_docs/700words.csv
# 1  파일 제목: 700words.csv\n 내용: title: 가계수지\ncontent...  ./raw_docs/700words.csv
# 2  파일 제목: 700words.csv\n 내용: title: 가계순저축률\nconte...  ./raw_docs/700words.csv
# 3  파일 제목: 700words.csv\n 내용: title: 가계신용통계\nconte...  ./raw_docs/700words.csv
# 4  파일 제목: 700words.csv\n 내용: title: 가계처분가능소득\ncon...  ./raw_docs/700words.csv
#
#   start_end_idx                                           metadata
# 0      [0, 522]  {'last_modified_datetime': '2024-10-24', 'next...
# 1      [0, 453]  {'last_modified_datetime': '2024-10-24', 'next...
# 2      [0, 422]  {'last_modified_datetime': '2024-10-24', 'next...
# 3      [0, 256]  {'last_modified_datetime': '2024-10-24', 'next...
# 4      [0, 447]  {'last_modified_datetime': '2024-10-24', 'next...
# ---------------------------------
#                                  doc_id  \
# 0  b1073b6c-23cf-429e-ac15-aa3ef8616ecc
# 1  8cfe4624-ce0e-4f0a-9e6e-e54c1d2a1d6d
# 2  9b54e503-b0ff-4169-a213-430621e7e540
# 3  6c82a4d5-8322-44f4-b27f-ab88d1c914c4
# 4  c30d37f2-7faa-4d36-ba1a-66f4707f7d73
#
#                                             contents                     path  \
# 0  파일 제목: 700words.csv\n 내용: title: 가계부실위험지수(HDRI...  ./raw_docs/700words.csv
# 1  파일 제목: 700words.csv\n 내용: title: 가계수지\ncontent...  ./raw_docs/700words.csv
# 2  파일 제목: 700words.csv\n 내용: title: 가계순저축률\nconte...  ./raw_docs/700words.csv
# 3  파일 제목: 700words.csv\n 내용: title: 가계신용통계\nconte...  ./raw_docs/700words.csv
# 4  파일 제목: 700words.csv\n 내용: title: 가계처분가능소득\ncon...  ./raw_docs/700words.csv
#
#   start_end_idx                                           metadata
# 0      [0, 522]  {'last_modified_datetime': '2024-10-24', 'next...
# 1      [0, 453]  {'last_modified_datetime': '2024-10-24', 'next...
# 2      [0, 422]  {'last_modified_datetime': '2024-10-24', 'next...
# 3      [0, 256]  {'last_modified_datetime': '2024-10-24', 'next...
# 4      [0, 447]  {'last_modified_datetime': '2024-10-24', 'next...
# ---------------------------------
#                                  doc_id  \
# 0  547110fd-56ee-4adc-92e2-c4db61d8b61d
# 1  c14c15c8-e144-4ed4-b562-ee50f298c197
# 2  d70d5f1f-925c-43ce-b904-1f274f850f55
# 3  a4996dfd-255a-4b1e-bcb2-edddedce68d8
# 4  4e26df6e-d84b-4291-b50a-e835a65e17e3
#
#                                             contents                     path  \
# 0  파일 제목: 700words.csv\n 내용: title: 가계부실위험지수(HDRI...  ./raw_docs/700words.csv
# 1  파일 제목: 700words.csv\n 내용: title: 가계수지\ncontent...  ./raw_docs/700words.csv
# 2  파일 제목: 700words.csv\n 내용: title: 가계순저축률\nconte...  ./raw_docs/700words.csv
# 3  파일 제목: 700words.csv\n 내용: title: 가계신용통계\nconte...  ./raw_docs/700words.csv
# 4  파일 제목: 700words.csv\n 내용: title: 가계처분가능소득\ncon...  ./raw_docs/700words.csv
#
#   start_end_idx                                           metadata
# 0      [0, 522]  {'last_modified_datetime': '2024-10-24', 'next...
# 1      [0, 453]  {'last_modified_datetime': '2024-10-24', 'next...
# 2      [0, 422]  {'last_modified_datetime': '2024-10-24', 'next...
# 3      [0, 256]  {'last_modified_datetime': '2024-10-24', 'next...
# 4      [0, 447]  {'last_modified_datetime': '2024-10-24', 'next...
# ---------------------------------
#                                  doc_id  \
# 0  c30dfccc-6a1f-4bab-9a80-6edadf68721c
# 1  cdb5c380-796b-4f16-b314-69d95879b239
# 2  bda85871-c2eb-44d8-afbf-25578f171ed1
# 3  43dbdeb1-b426-42b4-9723-4c400e90bc71
# 4  29d2e7ef-7b0a-45f1-97a0-81eb2ebf180a
#
#                                             contents                     path  \
# 0  파일 제목: 700words.csv\n 내용: title: 가계부실위험지수(HDRI...  ./raw_docs/700words.csv
# 1  파일 제목: 700words.csv\n 내용: 가계부실위험지수는 가구의 DSR과 D...  ./raw_docs/700words.csv
# 2  파일 제목: 700words.csv\n 내용: 위험가구는 소득 및 자산 측면에서 모...  ./raw_docs/700words.csv
# 3  파일 제목: 700words.csv\n 내용: 다만 위험 및 고위험 가구는 가구의 ...  ./raw_docs/700words.csv
# 4  파일 제목: 700words.csv\n 내용: related_keyword: 총부채...  ./raw_docs/700words.csv
#
#   start_end_idx                                           metadata
# 0      [0, 213]  {'last_modified_datetime': '2024-10-24', 'next...
# 1    [214, 309]  {'last_modified_datetime': '2024-10-24', 'next...
# 2    [310, 398]  {'last_modified_datetime': '2024-10-24', 'next...
# 3    [399, 490]  {'last_modified_datetime': '2024-10-24', 'next...
# 4    [491, 522]  {'last_modified_datetime': '2024-10-24', 'next...
# ---------------------------------
#                                  doc_id  \
# 0  8eb8f7e5-e91f-4016-a1bb-bad5e755d50c
# 1  dde38eb1-7465-47bc-84da-fec24ccae16b
# 2  a5bb2c83-a184-41f3-916b-b7faf5e01554
# 3  f6fc0c72-6f20-4698-8362-b625e3335dae
# 4  85a9198a-f6dd-4b3b-a5ac-d0392a6216e2
#
#                                             contents                     path  \
# 0  title: 가계부실위험지수(HDRI)\ncontent: 가구의 소득 흐름은 물론 ...  ./raw_docs/700words.csv
# 1  위험가구는 소득 및 자산 측면에서 모두 취약한 ‘고위험가구’, 자산 측면에서 취약한...  ./raw_docs/700words.csv
# 2  title: 가계수지\ncontent: 가정에서 일정 기간의 수입(명목소득)과 지출...  ./raw_docs/700words.csv
# 3                        related_keyword: 경상수지, 재정수지  ./raw_docs/700words.csv
# 4  title: 가계순저축률\ncontent: 일반적으로 저축률은 저축액을 처분가능소득...  ./raw_docs/700words.csv
#
#   start_end_idx                                           metadata
# 0      [0, 309]  {'last_modified_datetime': '2024-10-24', 'next...
# 1    [310, 522]  {'last_modified_datetime': '2024-10-24', 'next...
# 2      [0, 426]  {'last_modified_datetime': '2024-10-24', 'next...
# 3    [427, 453]  {'last_modified_datetime': '2024-10-24', 'next...
# 4      [0, 362]  {'last_modified_datetime': '2024-10-24', 'next...

# %%
console.print(chunk_7.contents[0])
# Out:
# title: 가계부실위험지수(HDRI)
# content: 가구의 소득 흐름은 물론 금융 및 실물 자산까지 종합적으로 고려하여 가계부채의 부실위험을 평가하는 지표로,
# 가계의 채무상환능력을 소득 측면에서 평가하는 원리금상 환비율(DSR; Debt Service Ratio)과 자산 측면에서 평가하는
# 부채/자산비율(DTA; Debt To Asset Ratio)을 결합하여 산출한 지수이다. 가계부실위험지수는 가구의 DSR과 DTA가 각각 40%,
# 100%일 때 100의 값을 갖도록 설정되어 있으며, 동 지수가 100을 초과하는 가구를 ‘위험가구’로 분류한다.

# %%
console.print(chunk_7.contents[1])
# Out:
# 위험가구는 소득 및 자산 측면에서 모두 취약한 ‘고위험가구’, 자산 측면에서 취약한 ‘고DTA가구’, 소득 측면에서 취약한
# ‘고DSR가구’로 구분할 수 있다. 다만 위험 및 고위험 가구는 가구의 채무상환능력 취약성 정도를 평가하기 위한 것이며
# 이들 가구가 당장 채무상환 불이행, 즉 임계상황에 직면한 것을 의미하지 않는다.
# related_keyword: 총부채원리금상환비율(DSR)
